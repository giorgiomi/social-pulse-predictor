# %% [markdown]
# ## First try EDA

# %%
import pandas as pd
import seaborn as sns

# %%
# Load df
df = pd.read_csv("../data/processed/twitter_weather.csv")

# %%
df
# Out:
#              date   time  timestamp_x        user      municipality.name  \
# 0      2013-11-01  00:04   1383260656  5fd4f31f75                 Trento
# 1      2013-11-01  00:01   1383260474  68c0e98182                Pinzolo
# 2      2013-11-01  00:43   1383262983  abe21fc052               Cavalese
# 3      2013-11-01  00:38   1383262717  94d1efbbfd               Rovereto
# 4      2013-11-01  00:45   1383263140  d261d03075  San Michele all'Adige
# ...           ...    ...          ...         ...                    ...
# 27931  2013-12-31  00:25   1388445948  826558e00e          Vigo di Fassa
# 27932  2013-12-29  13:12   1388319166  06e9b1cdff               Predazzo
# 27933  2013-11-19  00:51   1384818699  e61ce711d3      Sant'Orsola Terme
# 27934  2013-11-23  09:49   1385196576  e61ce711d3      Sant'Orsola Terme
# 27935  2013-12-31  16:31   1388503893  e61ce711d3       Palù del Fersina
#
#       language  hour_blocks           geometry_x station  elevation  \
# ...

# %%
sns.pairplot(df)
# Out:
# /usr/local/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
